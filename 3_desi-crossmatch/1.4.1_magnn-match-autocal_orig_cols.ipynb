# %%
import sys
sys.path.append('../')
sys.path.append('/Users/sdbykov/work/my_packages/nway')

# %%
from scripts.utils import data_path, set_mpl
from scripts.cross_match_scripts import fits_to_pandas
import pandas as pd
import numpy as np
import seaborn as sns
import nway_python_api as nway
# %matplotlib inline
# Out:
# matplotlib settings set
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
# matplotlib settings set
# This is NWAY Python API
# nwaylib file /Users/sdbykov/work/my_packages/nway/nwaylib/__init__.py

# %% [markdown]
# # Nway run in photometric prior mode
#
#  (autocalibration but of all available nnmags per source -> spurious information enhancement!!!)

# %%
magnitude_columns = [
                    ('nnmag_grz_orig', 'auto'),
                    ('nnmag_grzw1_orig', 'auto'),
                    ('nnmag_grzw1w2_orig', 'auto'),
                    ('rel_dered_mag_g_orig', 'auto'),
                    ('rel_dered_mag_r_orig', 'auto'),
                    ('rel_dered_mag_z_orig', 'auto'),
                    ('rel_dered_g_r_orig', 'auto'),
                    ('rel_dered_r_z_orig', 'auto'),
                    ('rel_dered_g_z_orig', 'auto'),
                    ]

ero_table = nway.table_from_fits(data_path+'ERO_lhpv_03_23_sd01_a15_g14.fits')
desi_table = nway.table_from_fits(data_path+'desi_lh.fits', poserr_value=0.1, magnitude_columns=magnitude_columns)
ero_pandas = fits_to_pandas('ERO_lhpv_03_23_sd01_a15_g14.fits')
desi_pandas = fits_to_pandas('desi_lh.fits')

ero_ctps_pandas = pd.read_pickle(data_path+'validation_ctps_ero_desi_lh.pkl')
ero_pandas = ero_pandas.merge(ero_ctps_pandas, on='ID', how='left')

nway_args = {'match_radius':30, 'prior_completeness':1,'mag_include_radius': 3.0,
'store_mag_hists': True,}

ero_pandas
# Out:
#       EROSITA                        ID          RA        DEC   pos_err  \
# 0           0  b'SRGe J103744.3+571156'  159.434594  57.198788  0.656740
# 1           1  b'SRGe J110137.5+572926'  165.406353  57.490464  0.689910
# 2           2  b'SRGe J110537.6+585120'  166.406669  58.855424  0.668180
# 3           3  b'SRGe J102349.9+563347'  155.958041  56.563186  0.652214
# 4           4  b'SRGe J105057.2+593215'  162.738144  59.537414  0.656779
# ...       ...                       ...         ...        ...       ...
# 9210     9210  b'SRGe J102315.1+561957'  155.813071  56.332561  3.950350
# 9211     9211  b'SRGe J102332.5+562524'  155.885436  56.423270  3.220603
# 9212     9212  b'SRGe J102235.0+561919'  155.645874  56.321872  3.025501
# 9213     9213  b'SRGe J102223.5+562357'  155.597875  56.399058  3.296691
# 9214     9214  b'SRGe J104406.3+545413'  161.026353  54.903612  3.084945
#
#          ML_FLUX_0 desi_id_true_ctp
# 0     3.284168e-12              NaN
# 1     1.969860e-12              NaN
# 2     1.505411e-12              NaN
# 3     1.001123e-12              NaN
# 4     9.137326e-13              NaN
# ...            ...              ...
# 9210  1.637604e-15              NaN
# 9211  1.608667e-15              NaN
# 9212  1.595806e-15              NaN
# 9213  1.532857e-15              NaN
# 9214  1.519228e-15              NaN
#
# [9215 rows x 7 columns]

# %%
nway_res_ero = nway.nwaylib.nway_match(
[ero_table, desi_table],
**nway_args
)
# Out:
#     adding angular separation columns
# matching: 145069 matches after filtering by search radius
# Primary catalogue "EROSITA" (9215), density gives 2.10e+07 objects on entire sky
# Catalogue "DESI" (2418574), density gives 2.39e+09 objects on entire sky
# Computing distance-based probabilities ...
#     correcting for unrelated associations ...
# 100%|██████████| 9215/9215 [00:04<00:00, 2247.55it/s]
# Incorporating bias "DESI:nnmag_grz_orig" ...
# magnitude histogram of column "DESI_nnmag_grz_orig": 4928 secure matches, 5661 insecure matches and 1747586 secure non-matches of 2418574 total entries (1752514 valid)
# magnitude histogram stored to "DESI_nnmag_grz_orig_fit.txt".
# /Users/sdbykov/work/my_packages/nway/nwaylib/__init__.py:376: RuntimeWarning: divide by zero encountered in log10
#   weights = log10(func(magcol))
# Incorporating bias "DESI:nnmag_grzw1_orig" ...
# magnitude histogram of column "DESI_nnmag_grzw1_orig": 4587 secure matches, 5661 insecure matches and 1183231 secure non-matches of 2418574 total entries (1187818 valid)
# magnitude histogram stored to "DESI_nnmag_grzw1_orig_fit.txt".
# Incorporating bias "DESI:nnmag_grzw1w2_orig" ...
# magnitude histogram of column "DESI_nnmag_grzw1w2_orig": 4285 secure matches, 5661 insecure matches and 719240 secure non-matches of 2418574 total entries (723525 valid)
# magnitude histogram stored to "DESI_nnmag_grzw1w2_orig_fit.txt".
# Incorporating bias "DESI:rel_dered_mag_g_orig" ...
# magnitude histogram of column "DESI_rel_dered_mag_g_orig": 5132 secure matches, 5661 insecure matches and 1986803 secure non-matches of 2418574 total entries (1991935 valid)
# magnitude histogram stored to "DESI_rel_dered_mag_g_orig_fit.txt".
# Incorporating bias "DESI:rel_dered_mag_r_orig" ...
# magnitude histogram of column "DESI_rel_dered_mag_r_orig": 5338 secure matches, 5661 insecure matches and 2124272 secure non-matches of 2418574 total entries (2129610 valid)
# magnitude histogram stored to "DESI_rel_dered_mag_r_orig_fit.txt".
# Incorporating bias "DESI:rel_dered_mag_z_orig" ...
# magnitude histogram of column "DESI_rel_dered_mag_z_orig": 5485 secure matches, 5661 insecure matches and 2254220 secure non-matches of 2418574 total entries (2259705 valid)
# magnitude histogram stored to "DESI_rel_dered_mag_z_orig_fit.txt".
# Incorporating bias "DESI:rel_dered_g_r_orig" ...
# magnitude histogram of column "DESI_rel_dered_g_r_orig": 5029 secure matches, 5661 insecure matches and 1864092 secure non-matches of 2418574 total entries (1869121 valid)
# magnitude histogram stored to "DESI_rel_dered_g_r_orig_fit.txt".
# Incorporating bias "DESI:rel_dered_r_z_orig" ...
# magnitude histogram of column "DESI_rel_dered_r_z_orig": 5229 secure matches, 5661 insecure matches and 2000307 secure non-matches of 2418574 total entries (2005536 valid)
# magnitude histogram stored to "DESI_rel_dered_r_z_orig_fit.txt".
# Incorporating bias "DESI:rel_dered_g_z_orig" ...
# magnitude histogram of column "DESI_rel_dered_g_z_orig": 5006 secure matches, 5661 insecure matches and 1836214 secure non-matches of 2418574 total entries (1841220 valid)
# magnitude histogram stored to "DESI_rel_dered_g_z_orig_fit.txt".
# Computing final probabilities ...
#     grouping by primary catalogue ID and flagging ...

# %%
os.system('rm DESI*_fit.txt')
# Out:
# rm: DESI*_fit.txt: No such file or directory
# 256
